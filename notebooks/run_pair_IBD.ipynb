# %% [markdown]
# # Run and plot IBD of pairs of Individuals

# %%
import socket as socket
import os as os
import sys as sys
import numpy as np
import matplotlib.pyplot as plt
socket_name = socket.gethostname()
print(socket_name)

if socket_name.startswith("compute-"):
    print("HSM O2 Computational partition detected.")
    path = "/n/groups/reich/hringbauer/git/hapBLOCK/"  # The Path on Harvard Cluster
    sys.path.append("/n/groups/reich/hringbauer/git/hapBLOCK/python3/") 
    
elif socket_name.startswith("bionc"):
    print("Leipzig Cluster detected!")
    path = "/mnt/archgen/users/hringbauer/"
    sys.path.append("/mnt/archgen/users/hringbauer/git/hapBLOCK/python3/") 
    
else: 
    raise RuntimeWarning("Not compatible machine. Check!!")

os.chdir(path)  # Set the right Path (in line with Atom default)
print(os.getcwd())

#from main import HMM_Full
from ancIBD.run import hapBLOCK_chrom, run_plot_pair
#from plot.plot_posterior import plot_posterior, plot_posterior_panel

### hapsburgImport
#sys.path.insert(0,"/n/groups/reich/hringbauer/git/HAPSBURG/package/")
#from hapsburg.PackagesSupport.parallel_runs.helper_functions import combine_individual_data

#sys.path.insert(0,"/n/groups/reich/hringbauer/git/hapBLOCK/package/")  # hack to get development package first in path
#from hapBLOCK.IO.h5_load import get_opp_homos_f
# Out:
# bionc21
# Leipzig Cluster detected!
# /mnt/archgen/users/hringbauer

# %%
post = run_plot_pair(path_h5='/mnt/archgen/users/hringbauer/data/GRG/hdf5/processed/ch',
                     iids=['GRG059.A01', 'GRG079.A01'], ch=8, min_cm=4, 
                     plot=True, l_model="hdf5", p_col="", xlim=[],
                     folder_out="", output=False) # ./output/empirical/test2/" "./output/empirical/punic"
# Out:
# Filtering to 0.99 GP variants: 0.686x
# Filtering to 0.99 GP variants: 0.829x
# Filtering to common GP variants: 0.621x
# Plotting 61133 markers

# %%
ost = run_plot_pair(path_h5='/mnt/archgen/users/hringbauer/data/GRG/hdf5/processed/ch',
                     iids=['GRG079.A01', 'GRG023.A01'], ch=8, min_cm=4, 
                     plot=True, l_model="hdf5", p_col="", xlim=[],
                     folder_out="", output=False) # ./output/empirical/test2/" "./output/empirical/punic"
# Out:
# Filtering to 0.99 GP variants: 0.829x
# Filtering to 0.99 GP variants: 0.579x
# Filtering to common GP variants: 0.532x
# Plotting 61133 markers

# %%
post = run_plot_pair(path_h5='/mnt/archgen/users/hringbauer/data/GRG/hdf5/processed/ch',
                     iids=['GRG107.A01', 'GRG057.A01'], ch=13, min_cm=4, 
                     plot=True, l_model="hdf5", p_col="", xlim=[],
                     folder_out="", output=False) # ./output/empirical/test2/" "./output/empirical/punic"
# Out:
# Filtering to 0.99 GP variants: 0.795x
# Filtering to 0.99 GP variants: 0.644x
# Filtering to common GP variants: 0.570x
# Plotting 39018 markers

# %%
post = run_plot_pair(path_h5='/mnt/archgen/users/hringbauer/data/GRG/hdf5/processed/ch',
                     iids=['GRG026.A01', 'GRG037.A01'], ch=3, min_cm=4, 
                     plot=True, l_model="hdf5", p_col="", xlim=[],
                     folder_out="", output=False)
# Out:
# Filtering to 0.99 GP variants: 0.817x
# Filtering to 0.99 GP variants: 0.771x
# Filtering to common GP variants: 0.697x
# Plotting 77652 markers

# %%
post = run_plot_pair(path_h5='/mnt/archgen/users/hringbauer/data/GRG/hdf5/processed/ch',
                     iids=['GRG014.A01', 'GRG015.A02'], ch=3, min_cm=4, 
                     plot=True, l_model="hdf5", p_col="", xlim=[],
                     folder_out="", output=False)
# Out:
# Filtering to 0.99 GP variants: 0.878x
# Filtering to 0.99 GP variants: 0.910x
# Filtering to common GP variants: 0.829x
# Plotting 77652 markers

# %%
post = run_plot_pair(path_h5='/mnt/archgen/users/hringbauer/data/GRG/hdf5/processed/ch',
                     iids=['GRG048.A01', 'GRG096.A01'], ch=5, min_cm=4, 
                     plot=True, l_model="hdf5", p_col="", xlim=[],
                     folder_out="", output=False)
# Out:
# Filtering to 0.99 GP variants: 0.759x
# Filtering to 0.99 GP variants: 0.890x
# Filtering to common GP variants: 0.714x
# Plotting 69399 markers
